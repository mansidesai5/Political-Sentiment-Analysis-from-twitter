# %% [markdown]
# <a href="https://colab.research.google.com/github/mansidesai5/Sentiment-analysiss/blob/masterr/Political_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as int
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
Modi=pd.read_csv("/content/drive/MyDrive/modii.csv")
RGandhi=pd.read_csv("/content/drive/MyDrive/RahulGandhi.csv")

# %%
Modi.head()
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2023-03-09 18:52:05+00:00  ModiAgainAt2024
# 1           1  2023-03-09 18:51:58+00:00  LuniyaSampatraj
# 2           2  2023-03-09 18:51:43+00:00      BabbalBagai
# 3           3  2023-03-09 18:51:41+00:00     AnjaliCS2003
# 4           4  2023-03-09 18:51:36+00:00    Rohit97102675
#
#                                                Tweet
# 0             @publictvnews @hd_kumaraswamy ನೋಡೋಣ...
# 1  @MDisrai92313417 @JEETEND22400821 @SirRavishFC...
# 2        @smritiirani Weldon Modi ji Tusi great 👍 ho
# 3  Roger Binny,President, BCCI presents framed ar...
# 4  @TheOneP94973812 @Abhishekmis93 @DROPPINLIBS B...

# %%
RGandhi.head()
# Out:
#    Unnamed: 0                       Date           User  \
# 0           0  2023-03-09 18:55:56+00:00      anandji72
# 1           1  2023-03-09 18:55:45+00:00  rajat_guptais
# 2           2  2023-03-09 18:55:41+00:00       BalaFun1
# 3           3  2023-03-09 18:55:38+00:00  JayParagShaah
# 4           4  2023-03-09 18:55:31+00:00      khaganadh
#
#                                                Tweet
# 0  @livemanish_ @RahulGandhi @SupriyaShrinate 2 o...
# 1  @newschatTM @drshamamohd @RahulGandhi @narendr...
# 2  @JudishRaj @vonbrauckmann @RahulGandhi Did you...
# 3  @GauravGogoiAsm @RahulGandhi Bhai, kya tweet k...
# 4  @the_hindu Rahul Gandhi just runs  his mouth w...

# %%
from textblob import TextBlob

modi_txt=TextBlob(Modi["Tweet"][2])
print(Modi["Tweet"][2])
print("Narendra Modi:", modi_txt.sentiment)

rgandhi_txt=TextBlob(RGandhi["Tweet"][10])
print(RGandhi["Tweet"][10])
print("Rahul Gandhi:", rgandhi_txt.sentiment)
# Out:
# @smritiirani Weldon Modi ji Tusi great 👍 ho
# Narendra Modi: Sentiment(polarity=0.8, subjectivity=0.75)
# @JudishRaj @vonbrauckmann @RahulGandhi Not surprising though. For a long time
# Rahul Gandhi: Sentiment(polarity=-0.19999999999999998, subjectivity=0.45)

# %%
def pol(Tweet) :
  return TextBlob(Tweet).sentiment.polarity

Modi["Polarity"] = Modi["Tweet"].apply(pol)
Modi.head(20)
# Out:
#     Unnamed: 0                       Date             User  \
# 0            0  2023-03-09 18:52:05+00:00  ModiAgainAt2024
# 1            1  2023-03-09 18:51:58+00:00  LuniyaSampatraj
# 2            2  2023-03-09 18:51:43+00:00      BabbalBagai
# 3            3  2023-03-09 18:51:41+00:00     AnjaliCS2003
# 4            4  2023-03-09 18:51:36+00:00    Rohit97102675
# 5            5  2023-03-09 18:51:34+00:00  Antonelloungolo
# 6            6  2023-03-09 18:51:31+00:00    HardikPatelHP
# 7            7  2023-03-09 18:51:29+00:00      balajiworld
# 8            8  2023-03-09 18:51:26+00:00       raminder_a
# 9            9  2023-03-09 18:51:26+00:00       ashokb2607
# 10          10  2023-03-09 18:51:21+00:00         GunaModi
# 11          11  2023-03-09 18:51:21+00:00       SevadalLKO
# 12          12  2023-03-09 18:51:10+00:00  drogon_dracarys
# 13          13  2023-03-09 18:50:50+00:00  f5031ee8d0ae426
# 14          14  2023-03-09 18:50:38+00:00   VijaySinghBJYM
# ...

# %%
RGandhi["Polarity"] = RGandhi["Tweet"].apply(pol)
RGandhi.head(20)
# Out:
#     Unnamed: 0                       Date             User  \
# 0            0  2023-03-09 18:55:56+00:00        anandji72
# 1            1  2023-03-09 18:55:45+00:00    rajat_guptais
# 2            2  2023-03-09 18:55:41+00:00         BalaFun1
# 3            3  2023-03-09 18:55:38+00:00    JayParagShaah
# 4            4  2023-03-09 18:55:31+00:00        khaganadh
# 5            5  2023-03-09 18:55:31+00:00  shivshankar6951
# 6            6  2023-03-09 18:55:25+00:00  Kamlesh77182774
# 7            7  2023-03-09 18:55:24+00:00     Krtavya_Path
# 8            8  2023-03-09 18:55:24+00:00  MahadebMahakal1
# 9            9  2023-03-09 18:55:12+00:00   Desh_Bhakt2022
# 10          10  2023-03-09 18:54:56+00:00         BalaFun1
# 11          11  2023-03-09 18:54:37+00:00  RahulVe37291829
# 12          12  2023-03-09 18:54:29+00:00         jdxjatin
# 13          13  2023-03-09 18:54:23+00:00    KillekarNitin
# 14          14  2023-03-09 18:54:20+00:00     MaikaalVaasi
# ...

# %%
import numpy as np

Modi["sentiment"] = np.where(Modi["Polarity"]>0,"Positive","Negative")
Modi["sentiment"][Modi["Polarity"]==0]="Neutral"
Modi.head(20)
# Out:
# <ipython-input-49-7034b1220771>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Unnamed: 0                       Date             User  \
# 0            0  2023-03-09 18:52:05+00:00  ModiAgainAt2024
# 1            1  2023-03-09 18:51:58+00:00  LuniyaSampatraj
# 2            2  2023-03-09 18:51:43+00:00      BabbalBagai
# 3            3  2023-03-09 18:51:41+00:00     AnjaliCS2003
# 4            4  2023-03-09 18:51:36+00:00    Rohit97102675
# 5            5  2023-03-09 18:51:34+00:00  Antonelloungolo
# 6            6  2023-03-09 18:51:31+00:00    HardikPatelHP
# 7            7  2023-03-09 18:51:29+00:00      balajiworld
# 8            8  2023-03-09 18:51:26+00:00       raminder_a
# 9            9  2023-03-09 18:51:26+00:00       ashokb2607
# ...

# %%
RGandhi["sentiment"] = np.where(RGandhi["Polarity"]>0,"Positive","Negative")
RGandhi["sentiment"][RGandhi["Polarity"]==0]="Neutral"
RGandhi.head(20)
# Out:
# <ipython-input-50-42d494f53514>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Unnamed: 0                       Date             User  \
# 0            0  2023-03-09 18:55:56+00:00        anandji72
# 1            1  2023-03-09 18:55:45+00:00    rajat_guptais
# 2            2  2023-03-09 18:55:41+00:00         BalaFun1
# 3            3  2023-03-09 18:55:38+00:00    JayParagShaah
# 4            4  2023-03-09 18:55:31+00:00        khaganadh
# 5            5  2023-03-09 18:55:31+00:00  shivshankar6951
# 6            6  2023-03-09 18:55:25+00:00  Kamlesh77182774
# 7            7  2023-03-09 18:55:24+00:00     Krtavya_Path
# 8            8  2023-03-09 18:55:24+00:00  MahadebMahakal1
# 9            9  2023-03-09 18:55:12+00:00   Desh_Bhakt2022
# ...

# %%
print("Narendra Modi --")
Modi_neutral = Modi[Modi["Polarity"]==0]
print("Neutral :",Modi_neutral.shape)
Modi_pos = Modi[Modi["Polarity"]>0]
print("Positive :",Modi_pos.shape)
Modi_neg = Modi[Modi["Polarity"]<0]
print("Negative :",Modi_neg.shape)


print("\nRahul Gandhi --")
RGandhi_neutral = RGandhi[RGandhi["Polarity"]==0]
print("Neutral :",RGandhi_neutral.shape)
RGandhi_pos = RGandhi[RGandhi["Polarity"]>0]
print("Positive :",RGandhi_pos.shape)
RGandhi_neg = RGandhi[RGandhi["Polarity"]<0]
print("Negative :",RGandhi_neg.shape)
# Out:
# Narendra Modi --
# Neutral : (627, 6)
# Positive : (251, 6)
# Negative : (122, 6)
#
# Rahul Gandhi --
# Neutral : (628, 6)
# Positive : (235, 6)
# Negative : (137, 6)

# %%
#dropping the neutral values as it doesnt give such information.
print("Before dropping the neutral values. \nModi : (1000, 6) ", "\nGandhi : (1000, 6) ")

Modi.drop(Modi[Modi["Polarity"]==0].index,inplace = True)
RGandhi.drop(RGandhi[RGandhi["Polarity"]==0].index,inplace = True)
print("After dropping the neutral values. \nModi : ",Modi.shape, "\nGandhi :",RGandhi.shape)
# Out:
# Before dropping the neutral values.
# Modi : (1000, 6)
# Gandhi : (1000, 6)
# After dropping the neutral values.
# Modi :  (373, 6)
# Gandhi : (372, 6)

# %%
#equaling both the datasets size.

import numpy as np

np.random.seed(10)
no = 1
drop_index = np.random.choice(Modi.index,no,replace = False)
Modi = Modi.drop(drop_index)
print(df_Modi.shape)
# Out:
# (372, 6)

# %%
# counting pos and neg sentiments 

count_Modi = Modi.groupby('sentiment').count()
print("\nNarendra Modi\n",count_Modi)

count_RGandhi = RGandhi.groupby('sentiment').count()
print("\nRahul Gandhi\n",count_RGandhi)
# Out:
# Narendra Modi
#             Unnamed: 0  Date  User  Tweet  Polarity
# sentiment
# Negative          122   122   122    122       122
# Positive          250   250   250    250       250
#
# Rahul Gandhi
#             Unnamed: 0  Date  User  Tweet  Polarity
# sentiment
# Negative          137   137   137    137       137
# Positive          235   235   235    235       235

# %%
name = ['Narendra Modi','Rahul Gandhi']
list_pos = [count_Modi['Polarity'][1],count_RGandhi['Polarity'][1]]
list_neg = [count_Modi['Polarity'][0],count_RGandhi['Polarity'][0]]

import plotly.graph_objects as go

fig = go.Figure(data = [go.Bar(name='+ve',x=name,y=list_pos),go.Bar(name='-ve',x=name,y=list_neg)])
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#removing @ and urls from the dataset.


text=" ".join(text for text in Modi.Tweet)
text=" ".join(filter(lambda x:x[0]!= '@',text.split()))

import re
text=re.sub(r"http\S+","",text)
print("there have {} in words in all text.".format(len(text)))
WC = WordCloud(stopwords = STOPWORDS, background_color="white").generate(text)

plt.figure(figsize=(15,15))
plt.imshow(WC, interpolation='bilinear')
# Out:
# there have 64368 in words in all text.

# %%
text=" ".join(text for text in RGandhi.Tweet)
text=" ".join(filter(lambda x:x[0]!= '@',text.split()))

import re
text=re.sub(r"http\S+","",text)
print("there have {} in words in all text.".format(len(text)))
WC = WordCloud(stopwords = STOPWORDS, background_color="white").generate(text)

plt.figure(figsize=(15,15))
plt.imshow(WC, interpolation='bilinear')
# Out:
# there have 57533 in words in all text.
